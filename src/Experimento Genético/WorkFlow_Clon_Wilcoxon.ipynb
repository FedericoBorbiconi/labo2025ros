# %% [markdown]
# # 8 WorkFlow  Semillerio

# %% [markdown]
# ### 8.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 8.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %% [markdown]
# *  Si usted eligió modalidad *Gerencial* entonces NO debe modificar nada, su liderazgo logró que otras trabajaron por usted
# *  Si usted eligió modalidad de *Analista Junior*, entonces donde dice archivo="gerencial_competencia_2025.csv.gz"  lo debe cambiar por  archivo="analistajr_competencia_2025.csv.gz"
# *  Si usted eligió modalidad *Analista Senior*,  ya se las ingenierá SIN preguntar !

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/labo1r"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 8.3  Workflow Semillerio

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 10 01:43:58 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used      (Mb)   gc trigger (Mb)    max used   (Mb)
# Ncells   2139304  114.3    4183897   223.5    2964021   158.3
# Vcells 414652445 3163.6 3595412124 27430.9 3575184462 27276.5

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %% [markdown]
# ### Usted DEBE ambiar "PARAM experimento" cada vez que desee correr un nuevo experimento

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 314159

PARAM$experimento <- "-clon-ff100-Wilcoxon"
PARAM$dataset <- "analistasr_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 8.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 8.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/buckets/b1/datasets/", PARAM$dataset))

# %% [markdown]
# #### 8.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 8.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 8.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]


dataset[, ctrx_quarter_clon :=  ctrx_quarter ]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "active_quarter"
#   [4] "cliente_vip"
#   [5] "internet"
#   [6] "cliente_edad"
#   [7] "cliente_antiguedad"
#   [8] "mrentabilidad"
#   [9] "mrentabilidad_annual"
#  [10] "mcomisiones"
#  [11] "mactivos_margen"
#  [12] "mpasivos_margen"
#  [13] "cproductos"
#  [14] "tcuentas"
#  [15] "ccuenta_corriente"
#  [16] "mcuenta_corriente_adicional"
#  [17] "mcuenta_corriente"
#  [18] "ccaja_ahorro"
#  [19] "mcaja_ahorro"
#  [20] "mcaja_ahorro_adicional"
#  [21] "mcaja_ahorro_dolares"
#  [22] "cdescubierto_preacordado"
#  [23] "mcuentas_saldo"
#  [24] "ctarjeta_debito"
#  [25] "ctarjeta_debito_transacciones"
#  [26] "mautoservicio"
#  [27] "ctarjeta_visa"
#  [28] "ctarjeta_visa_transacciones"
#  [29] "mtarjeta_visa_consumo"
#  [30] "ctarjeta_master"
#  [31] "ctarjeta_master_transacciones"
#  [32] "mtarjeta_master_consumo"
#  [33] "cprestamos_personales"
#  [34] "mprestamos_personales"
#  [35] "cprestamos_prendarios"
#  [36] "mprestamos_prendarios"
#  [37] "cprestamos_hipotecarios"
#  [38] "mprestamos_hipotecarios"
#  [39] "cplazo_fijo"
#  [40] "mplazo_fijo_dolares"
#  [41] "mplazo_fijo_pesos"
#  [42] "cinversion1"
#  [43] "minversion1_pesos"
#  [44] "minversion1_dolares"
#  [45] "cinversion2"
#  [46] "minversion2"
#  [47] "cseguro_vida"
#  [48] "cseguro_auto"
#  [49] "cseguro_vivienda"
#  [50] "cseguro_accidentes_personales"
#  [51] "ccaja_seguridad"
#  [52] "cpayroll_trx"
#  [53] "mpayroll"
#  [54] "mpayroll2"
#  [55] "cpayroll2_trx"
#  [56] "ccuenta_debitos_automaticos"
#  [57] "mcuenta_debitos_automaticos"
#  [58] "ctarjeta_visa_debitos_automaticos"
#  [59] "mttarjeta_visa_debitos_automaticos"
#  [60] "ctarjeta_master_debitos_automaticos"
#  [61] "mttarjeta_master_debitos_automaticos"
#  [62] "cpagodeservicios"
#  [63] "mpagodeservicios"
#  [64] "cpagomiscuentas"
#  [65] "mpagomiscuentas"
#  [66] "ccajeros_propios_descuentos"
#  [67] "mcajeros_propios_descuentos"
#  [68] "ctarjeta_visa_descuentos"
#  [69] "mtarjeta_visa_descuentos"
#  [70] "ctarjeta_master_descuentos"
#  [71] "mtarjeta_master_descuentos"
#  [72] "ccomisiones_mantenimiento"
#  [73] "mcomisiones_mantenimiento"
#  [74] "ccomisiones_otras"
#  [75] "mcomisiones_otras"
#  [76] "cforex"
#  [77] "cforex_buy"
#  [78] "mforex_buy"
#  [79] "cforex_sell"
#  [80] "mforex_sell"
#  [81] "ctransferencias_recibidas"
#  [82] "mtransferencias_recibidas"
#  [83] "ctransferencias_emitidas"
#  [84] "mtransferencias_emitidas"
#  [85] "cextraccion_autoservicio"
#  [86] "mextraccion_autoservicio"
#  [87] "ccheques_depositados"
#  [88] "mcheques_depositados"
#  [89] "ccheques_emitidos"
#  [90] "mcheques_emitidos"
#  [91] "ccheques_depositados_rechazados"
#  [92] "mcheques_depositados_rechazados"
#  [93] "ccheques_emitidos_rechazados"
#  [94] "mcheques_emitidos_rechazados"
#  [95] "tcallcenter"
#  [96] "ccallcenter_transacciones"
#  [97] "thomebanking"
#  [98] "chomebanking_transacciones"
#  [99] "ccajas_transacciones"
# [100] "ccajas_consultas"
# [101] "ccajas_depositos"
# [102] "ccajas_extracciones"
# [103] "ccajas_otras"
# [104] "catm_trx"
# [105] "matm"
# [106] "catm_trx_other"
# [107] "matm_other"
# [108] "ctrx_quarter"
# [109] "tmobile_app"
# [110] "cmobile_app_trx"
# [111] "Master_delinquency"
# [112] "Master_status"
# [113] "Master_mfinanciacion_limite"
# [114] "Master_Fvencimiento"
# [115] "Master_Finiciomora"
# [116] "Master_msaldototal"
# [117] "Master_msaldopesos"
# [118] "Master_msaldodolares"
# [119] "Master_mconsumospesos"
# [120] "Master_mconsumosdolares"
# [121] "Master_mlimitecompra"
# [122] "Master_madelantopesos"
# [123] "Master_madelantodolares"
# [124] "Master_fultimo_cierre"
# [125] "Master_mpagado"
# [126] "Master_mpagospesos"
# [127] "Master_mpagosdolares"
# [128] "Master_fechaalta"
# [129] "Master_mconsumototal"
# [130] "Master_cconsumos"
# [131] "Master_cadelantosefectivo"
# [132] "Master_mpagominimo"
# [133] "Visa_delinquency"
# [134] "Visa_status"
# [135] "Visa_mfinanciacion_limite"
# [136] "Visa_Fvencimiento"
# [137] "Visa_Finiciomora"
# [138] "Visa_msaldototal"
# [139] "Visa_msaldopesos"
# [140] "Visa_msaldodolares"
# [141] "Visa_mconsumospesos"
# [142] "Visa_mconsumosdolares"
# [143] "Visa_mlimitecompra"
# [144] "Visa_madelantopesos"
# [145] "Visa_madelantodolares"
# [146] "Visa_fultimo_cierre"
# [147] "Visa_mpagado"
# [148] "Visa_mpagospesos"
# [149] "Visa_mpagosdolares"
# [150] "Visa_fechaalta"
# [151] "Visa_mconsumototal"
# [152] "Visa_cconsumos"
# [153] "Visa_cadelantosefectivo"
# [154] "Visa_mpagominimo"
# [155] "clase_ternaria"
# [156] "kmes"
# [157] "mpayroll_sobre_edad"
# [158] "ctrx_quarter_clon"

# %% [markdown]
# #### 8.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 8.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico
# ordeno el dataset
setorder(dataset, numero_de_cliente, foto_mes)

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 778
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "active_quarter"
#   [4] "cliente_vip"
#   [5] "internet"
#   [6] "cliente_edad"
#   [7] "cliente_antiguedad"
#   [8] "mrentabilidad"
#   [9] "mrentabilidad_annual"
#  [10] "mcomisiones"
#  [11] "mactivos_margen"
#  [12] "mpasivos_margen"
#  [13] "cproductos"
#  [14] "tcuentas"
#  [15] "ccuenta_corriente"
#  [16] "mcuenta_corriente_adicional"
#  [17] "mcuenta_corriente"
#  [18] "ccaja_ahorro"
#  [19] "mcaja_ahorro"
#  [20] "mcaja_ahorro_adicional"
#  [21] "mcaja_ahorro_dolares"
#  [22] "cdescubierto_preacordado"
#  [23] "mcuentas_saldo"
#  [24] "ctarjeta_debito"
#  [25] "ctarjeta_debito_transacciones"
#  [26] "mautoservicio"
#  [27] "ctarjeta_visa"
#  [28] "ctarjeta_visa_transacciones"
#  [29] "mtarjeta_visa_consumo"
#  [30] "ctarjeta_master"
#  [31] "ctarjeta_master_transacciones"
#  [32] "mtarjeta_master_consumo"
#  [33] "cprestamos_personales"
#  [34] "mprestamos_personales"
#  [35] "cprestamos_prendarios"
#  [36] "mprestamos_prendarios"
#  [37] "cprestamos_hipotecarios"
#  [38] "mprestamos_hipotecarios"
#  [39] "cplazo_fijo"
#  [40] "mplazo_fijo_dolares"
#  [41] "mplazo_fijo_pesos"
#  [42] "cinversion1"
#  [43] "minversion1_pesos"
#  [44] "minversion1_dolares"
#  [45] "cinversion2"
#  [46] "minversion2"
#  [47] "cseguro_vida"
#  [48] "cseguro_auto"
#  [49] "cseguro_vivienda"
#  [50] "cseguro_accidentes_personales"
#  [51] "ccaja_seguridad"
#  [52] "cpayroll_trx"
#  [53] "mpayroll"
#  [54] "mpayroll2"
#  [55] "cpayroll2_trx"
#  [56] "ccuenta_debitos_automaticos"
#  [57] "mcuenta_debitos_automaticos"
#  [58] "ctarjeta_visa_debitos_automaticos"
#  [59] "mttarjeta_visa_debitos_automaticos"
#  [60] "ctarjeta_master_debitos_automaticos"
#  [61] "mttarjeta_master_debitos_automaticos"
#  [62] "cpagodeservicios"
#  [63] "mpagodeservicios"
#  [64] "cpagomiscuentas"
#  [65] "mpagomiscuentas"
#  [66] "ccajeros_propios_descuentos"
#  [67] "mcajeros_propios_descuentos"
#  [68] "ctarjeta_visa_descuentos"
#  [69] "mtarjeta_visa_descuentos"
#  [70] "ctarjeta_master_descuentos"
#  [71] "mtarjeta_master_descuentos"
#  [72] "ccomisiones_mantenimiento"
#  [73] "mcomisiones_mantenimiento"
#  [74] "ccomisiones_otras"
#  [75] "mcomisiones_otras"
#  [76] "cforex"
#  [77] "cforex_buy"
#  [78] "mforex_buy"
#  [79] "cforex_sell"
#  [80] "mforex_sell"
#  [81] "ctransferencias_recibidas"
#  [82] "mtransferencias_recibidas"
#  [83] "ctransferencias_emitidas"
#  [84] "mtransferencias_emitidas"
#  [85] "cextraccion_autoservicio"
#  [86] "mextraccion_autoservicio"
#  [87] "ccheques_depositados"
#  [88] "mcheques_depositados"
#  [89] "ccheques_emitidos"
#  [90] "mcheques_emitidos"
#  [91] "ccheques_depositados_rechazados"
#  [92] "mcheques_depositados_rechazados"
#  [93] "ccheques_emitidos_rechazados"
#  [94] "mcheques_emitidos_rechazados"
#  [95] "tcallcenter"
#  [96] "ccallcenter_transacciones"
#  [97] "thomebanking"
#  [98] "chomebanking_transacciones"
#  [99] "ccajas_transacciones"
# [100] "ccajas_consultas"
# [101] "ccajas_depositos"
# [102] "ccajas_extracciones"
# [103] "ccajas_otras"
# [104] "catm_trx"
# [105] "matm"
# [106] "catm_trx_other"
# [107] "matm_other"
# [108] "ctrx_quarter"
# [109] "tmobile_app"
# [110] "cmobile_app_trx"
# [111] "Master_delinquency"
# [112] "Master_status"
# [113] "Master_mfinanciacion_limite"
# [114] "Master_Fvencimiento"
# [115] "Master_Finiciomora"
# [116] "Master_msaldototal"
# [117] "Master_msaldopesos"
# [118] "Master_msaldodolares"
# [119] "Master_mconsumospesos"
# [120] "Master_mconsumosdolares"
# [121] "Master_mlimitecompra"
# [122] "Master_madelantopesos"
# [123] "Master_madelantodolares"
# [124] "Master_fultimo_cierre"
# [125] "Master_mpagado"
# [126] "Master_mpagospesos"
# [127] "Master_mpagosdolares"
# [128] "Master_fechaalta"
# [129] "Master_mconsumototal"
# [130] "Master_cconsumos"
# [131] "Master_cadelantosefectivo"
# [132] "Master_mpagominimo"
# [133] "Visa_delinquency"
# [134] "Visa_status"
# [135] "Visa_mfinanciacion_limite"
# [136] "Visa_Fvencimiento"
# [137] "Visa_Finiciomora"
# [138] "Visa_msaldototal"
# [139] "Visa_msaldopesos"
# [140] "Visa_msaldodolares"
# [141] "Visa_mconsumospesos"
# [142] "Visa_mconsumosdolares"
# [143] "Visa_mlimitecompra"
# [144] "Visa_madelantopesos"
# [145] "Visa_madelantodolares"
# [146] "Visa_fultimo_cierre"
# [147] "Visa_mpagado"
# [148] "Visa_mpagospesos"
# [149] "Visa_mpagosdolares"
# [150] "Visa_fechaalta"
# [151] "Visa_mconsumototal"
# [152] "Visa_cconsumos"
# [153] "Visa_cadelantosefectivo"
# [154] "Visa_mpagominimo"
# [155] "clase_ternaria"
# [156] "kmes"
# [157] "mpayroll_sobre_edad"
# [158] "ctrx_quarter_clon"
# [159] "active_quarter_lag1"
# [160] "cliente_vip_lag1"
# [161] "internet_lag1"
# [162] "cliente_edad_lag1"
# [163] "cliente_antiguedad_lag1"
# [164] "mrentabilidad_lag1"
# [165] "mrentabilidad_annual_lag1"
# [166] "mcomisiones_lag1"
# [167] "mactivos_margen_lag1"
# [168] "mpasivos_margen_lag1"
# [169] "cproductos_lag1"
# [170] "tcuentas_lag1"
# [171] "ccuenta_corriente_lag1"
# [172] "mcuenta_corriente_adicional_lag1"
# [173] "mcuenta_corriente_lag1"
# [174] "ccaja_ahorro_lag1"
# [175] "mcaja_ahorro_lag1"
# [176] "mcaja_ahorro_adicional_lag1"
# [177] "mcaja_ahorro_dolares_lag1"
# [178] "cdescubierto_preacordado_lag1"
# [179] "mcuentas_saldo_lag1"
# [180] "ctarjeta_debito_lag1"
# [181] "ctarjeta_debito_transacciones_lag1"
# [182] "mautoservicio_lag1"
# [183] "ctarjeta_visa_lag1"
# [184] "ctarjeta_visa_transacciones_lag1"
# [185] "mtarjeta_visa_consumo_lag1"
# [186] "ctarjeta_master_lag1"
# [187] "ctarjeta_master_transacciones_lag1"
# [188] "mtarjeta_master_consumo_lag1"
# [189] "cprestamos_personales_lag1"
# [190] "mprestamos_personales_lag1"
# [191] "cprestamos_prendarios_lag1"
# [192] "mprestamos_prendarios_lag1"
# [193] "cprestamos_hipotecarios_lag1"
# [194] "mprestamos_hipotecarios_lag1"
# [195] "cplazo_fijo_lag1"
# [196] "mplazo_fijo_dolares_lag1"
# [197] "mplazo_fijo_pesos_lag1"
# [198] "cinversion1_lag1"
# [199] "minversion1_pesos_lag1"
# [200] "minversion1_dolares_lag1"
# [201] "cinversion2_lag1"
# [202] "minversion2_lag1"
# [203] "cseguro_vida_lag1"
# [204] "cseguro_auto_lag1"
# [205] "cseguro_vivienda_lag1"
# [206] "cseguro_accidentes_personales_lag1"
# [207] "ccaja_seguridad_lag1"
# [208] "cpayroll_trx_lag1"
# [209] "mpayroll_lag1"
# [210] "mpayroll2_lag1"
# [211] "cpayroll2_trx_lag1"
# [212] "ccuenta_debitos_automaticos_lag1"
# [213] "mcuenta_debitos_automaticos_lag1"
# [214] "ctarjeta_visa_debitos_automaticos_lag1"
# [215] "mttarjeta_visa_debitos_automaticos_lag1"
# [216] "ctarjeta_master_debitos_automaticos_lag1"
# [217] "mttarjeta_master_debitos_automaticos_lag1"
# [218] "cpagodeservicios_lag1"
# [219] "mpagodeservicios_lag1"
# [220] "cpagomiscuentas_lag1"
# [221] "mpagomiscuentas_lag1"
# [222] "ccajeros_propios_descuentos_lag1"
# [223] "mcajeros_propios_descuentos_lag1"
# [224] "ctarjeta_visa_descuentos_lag1"
# [225] "mtarjeta_visa_descuentos_lag1"
# [226] "ctarjeta_master_descuentos_lag1"
# [227] "mtarjeta_master_descuentos_lag1"
# [228] "ccomisiones_mantenimiento_lag1"
# [229] "mcomisiones_mantenimiento_lag1"
# [230] "ccomisiones_otras_lag1"
# [231] "mcomisiones_otras_lag1"
# [232] "cforex_lag1"
# [233] "cforex_buy_lag1"
# [234] "mforex_buy_lag1"
# [235] "cforex_sell_lag1"
# [236] "mforex_sell_lag1"
# [237] "ctransferencias_recibidas_lag1"
# [238] "mtransferencias_recibidas_lag1"
# [239] "ctransferencias_emitidas_lag1"
# [240] "mtransferencias_emitidas_lag1"
# [241] "cextraccion_autoservicio_lag1"
# [242] "mextraccion_autoservicio_lag1"
# [243] "ccheques_depositados_lag1"
# [244] "mcheques_depositados_lag1"
# [245] "ccheques_emitidos_lag1"
# [246] "mcheques_emitidos_lag1"
# [247] "ccheques_depositados_rechazados_lag1"
# [248] "mcheques_depositados_rechazados_lag1"
# [249] "ccheques_emitidos_rechazados_lag1"
# [250] "mcheques_emitidos_rechazados_lag1"
# [251] "tcallcenter_lag1"
# [252] "ccallcenter_transacciones_lag1"
# [253] "thomebanking_lag1"
# [254] "chomebanking_transacciones_lag1"
# [255] "ccajas_transacciones_lag1"
# [256] "ccajas_consultas_lag1"
# [257] "ccajas_depositos_lag1"
# [258] "ccajas_extracciones_lag1"
# [259] "ccajas_otras_lag1"
# [260] "catm_trx_lag1"
# [261] "matm_lag1"
# [262] "catm_trx_other_lag1"
# [263] "matm_other_lag1"
# [264] "ctrx_quarter_lag1"
# [265] "tmobile_app_lag1"
# [266] "cmobile_app_trx_lag1"
# [267] "Master_delinquency_lag1"
# [268] "Master_status_lag1"
# [269] "Master_mfinanciacion_limite_lag1"
# [270] "Master_Fvencimiento_lag1"
# [271] "Master_Finiciomora_lag1"
# [272] "Master_msaldototal_lag1"
# [273] "Master_msaldopesos_lag1"
# [274] "Master_msaldodolares_lag1"
# [275] "Master_mconsumospesos_lag1"
# [276] "Master_mconsumosdolares_lag1"
# [277] "Master_mlimitecompra_lag1"
# [278] "Master_madelantopesos_lag1"
# [279] "Master_madelantodolares_lag1"
# [280] "Master_fultimo_cierre_lag1"
# [281] "Master_mpagado_lag1"
# [282] "Master_mpagospesos_lag1"
# [283] "Master_mpagosdolares_lag1"
# [284] "Master_fechaalta_lag1"
# [285] "Master_mconsumototal_lag1"
# [286] "Master_cconsumos_lag1"
# [287] "Master_cadelantosefectivo_lag1"
# [288] "Master_mpagominimo_lag1"
# [289] "Visa_delinquency_lag1"
# [290] "Visa_status_lag1"
# [291] "Visa_mfinanciacion_limite_lag1"
# [292] "Visa_Fvencimiento_lag1"
# [293] "Visa_Finiciomora_lag1"
# [294] "Visa_msaldototal_lag1"
# [295] "Visa_msaldopesos_lag1"
# [296] "Visa_msaldodolares_lag1"
# [297] "Visa_mconsumospesos_lag1"
# [298] "Visa_mconsumosdolares_lag1"
# [299] "Visa_mlimitecompra_lag1"
# [300] "Visa_madelantopesos_lag1"
# [301] "Visa_madelantodolares_lag1"
# [302] "Visa_fultimo_cierre_lag1"
# [303] "Visa_mpagado_lag1"
# [304] "Visa_mpagospesos_lag1"
# [305] "Visa_mpagosdolares_lag1"
# [306] "Visa_fechaalta_lag1"
# [307] "Visa_mconsumototal_lag1"
# [308] "Visa_cconsumos_lag1"
# [309] "Visa_cadelantosefectivo_lag1"
# [310] "Visa_mpagominimo_lag1"
# [311] "kmes_lag1"
# [312] "mpayroll_sobre_edad_lag1"
# [313] "ctrx_quarter_clon_lag1"
# [314] "active_quarter_lag2"
# [315] "cliente_vip_lag2"
# [316] "internet_lag2"
# [317] "cliente_edad_lag2"
# [318] "cliente_antiguedad_lag2"
# [319] "mrentabilidad_lag2"
# [320] "mrentabilidad_annual_lag2"
# [321] "mcomisiones_lag2"
# [322] "mactivos_margen_lag2"
# [323] "mpasivos_margen_lag2"
# [324] "cproductos_lag2"
# [325] "tcuentas_lag2"
# [326] "ccuenta_corriente_lag2"
# [327] "mcuenta_corriente_adicional_lag2"
# [328] "mcuenta_corriente_lag2"
# [329] "ccaja_ahorro_lag2"
# [330] "mcaja_ahorro_lag2"
# [331] "mcaja_ahorro_adicional_lag2"
# [332] "mcaja_ahorro_dolares_lag2"
# [333] "cdescubierto_preacordado_lag2"
# [334] "mcuentas_saldo_lag2"
# [335] "ctarjeta_debito_lag2"
# [336] "ctarjeta_debito_transacciones_lag2"
# [337] "mautoservicio_lag2"
# [338] "ctarjeta_visa_lag2"
# [339] "ctarjeta_visa_transacciones_lag2"
# [340] "mtarjeta_visa_consumo_lag2"
# [341] "ctarjeta_master_lag2"
# [342] "ctarjeta_master_transacciones_lag2"
# [343] "mtarjeta_master_consumo_lag2"
# [344] "cprestamos_personales_lag2"
# [345] "mprestamos_personales_lag2"
# [346] "cprestamos_prendarios_lag2"
# [347] "mprestamos_prendarios_lag2"
# [348] "cprestamos_hipotecarios_lag2"
# [349] "mprestamos_hipotecarios_lag2"
# [350] "cplazo_fijo_lag2"
# [351] "mplazo_fijo_dolares_lag2"
# [352] "mplazo_fijo_pesos_lag2"
# [353] "cinversion1_lag2"
# [354] "minversion1_pesos_lag2"
# [355] "minversion1_dolares_lag2"
# [356] "cinversion2_lag2"
# [357] "minversion2_lag2"
# [358] "cseguro_vida_lag2"
# [359] "cseguro_auto_lag2"
# [360] "cseguro_vivienda_lag2"
# [361] "cseguro_accidentes_personales_lag2"
# [362] "ccaja_seguridad_lag2"
# [363] "cpayroll_trx_lag2"
# [364] "mpayroll_lag2"
# [365] "mpayroll2_lag2"
# [366] "cpayroll2_trx_lag2"
# [367] "ccuenta_debitos_automaticos_lag2"
# [368] "mcuenta_debitos_automaticos_lag2"
# [369] "ctarjeta_visa_debitos_automaticos_lag2"
# [370] "mttarjeta_visa_debitos_automaticos_lag2"
# [371] "ctarjeta_master_debitos_automaticos_lag2"
# [372] "mttarjeta_master_debitos_automaticos_lag2"
# [373] "cpagodeservicios_lag2"
# [374] "mpagodeservicios_lag2"
# [375] "cpagomiscuentas_lag2"
# [376] "mpagomiscuentas_lag2"
# [377] "ccajeros_propios_descuentos_lag2"
# [378] "mcajeros_propios_descuentos_lag2"
# [379] "ctarjeta_visa_descuentos_lag2"
# [380] "mtarjeta_visa_descuentos_lag2"
# [381] "ctarjeta_master_descuentos_lag2"
# [382] "mtarjeta_master_descuentos_lag2"
# [383] "ccomisiones_mantenimiento_lag2"
# [384] "mcomisiones_mantenimiento_lag2"
# [385] "ccomisiones_otras_lag2"
# [386] "mcomisiones_otras_lag2"
# [387] "cforex_lag2"
# [388] "cforex_buy_lag2"
# [389] "mforex_buy_lag2"
# [390] "cforex_sell_lag2"
# [391] "mforex_sell_lag2"
# [392] "ctransferencias_recibidas_lag2"
# [393] "mtransferencias_recibidas_lag2"
# [394] "ctransferencias_emitidas_lag2"
# [395] "mtransferencias_emitidas_lag2"
# [396] "cextraccion_autoservicio_lag2"
# [397] "mextraccion_autoservicio_lag2"
# [398] "ccheques_depositados_lag2"
# [399] "mcheques_depositados_lag2"
# [400] "ccheques_emitidos_lag2"
# [401] "mcheques_emitidos_lag2"
# [402] "ccheques_depositados_rechazados_lag2"
# [403] "mcheques_depositados_rechazados_lag2"
# [404] "ccheques_emitidos_rechazados_lag2"
# [405] "mcheques_emitidos_rechazados_lag2"
# [406] "tcallcenter_lag2"
# [407] "ccallcenter_transacciones_lag2"
# [408] "thomebanking_lag2"
# [409] "chomebanking_transacciones_lag2"
# [410] "ccajas_transacciones_lag2"
# [411] "ccajas_consultas_lag2"
# [412] "ccajas_depositos_lag2"
# [413] "ccajas_extracciones_lag2"
# [414] "ccajas_otras_lag2"
# [415] "catm_trx_lag2"
# [416] "matm_lag2"
# [417] "catm_trx_other_lag2"
# [418] "matm_other_lag2"
# [419] "ctrx_quarter_lag2"
# [420] "tmobile_app_lag2"
# [421] "cmobile_app_trx_lag2"
# [422] "Master_delinquency_lag2"
# [423] "Master_status_lag2"
# [424] "Master_mfinanciacion_limite_lag2"
# [425] "Master_Fvencimiento_lag2"
# [426] "Master_Finiciomora_lag2"
# [427] "Master_msaldototal_lag2"
# [428] "Master_msaldopesos_lag2"
# [429] "Master_msaldodolares_lag2"
# [430] "Master_mconsumospesos_lag2"
# [431] "Master_mconsumosdolares_lag2"
# [432] "Master_mlimitecompra_lag2"
# [433] "Master_madelantopesos_lag2"
# [434] "Master_madelantodolares_lag2"
# [435] "Master_fultimo_cierre_lag2"
# [436] "Master_mpagado_lag2"
# [437] "Master_mpagospesos_lag2"
# [438] "Master_mpagosdolares_lag2"
# [439] "Master_fechaalta_lag2"
# [440] "Master_mconsumototal_lag2"
# [441] "Master_cconsumos_lag2"
# [442] "Master_cadelantosefectivo_lag2"
# [443] "Master_mpagominimo_lag2"
# [444] "Visa_delinquency_lag2"
# [445] "Visa_status_lag2"
# [446] "Visa_mfinanciacion_limite_lag2"
# [447] "Visa_Fvencimiento_lag2"
# [448] "Visa_Finiciomora_lag2"
# [449] "Visa_msaldototal_lag2"
# [450] "Visa_msaldopesos_lag2"
# [451] "Visa_msaldodolares_lag2"
# [452] "Visa_mconsumospesos_lag2"
# [453] "Visa_mconsumosdolares_lag2"
# [454] "Visa_mlimitecompra_lag2"
# [455] "Visa_madelantopesos_lag2"
# [456] "Visa_madelantodolares_lag2"
# [457] "Visa_fultimo_cierre_lag2"
# [458] "Visa_mpagado_lag2"
# [459] "Visa_mpagospesos_lag2"
# [460] "Visa_mpagosdolares_lag2"
# [461] "Visa_fechaalta_lag2"
# [462] "Visa_mconsumototal_lag2"
# [463] "Visa_cconsumos_lag2"
# [464] "Visa_cadelantosefectivo_lag2"
# [465] "Visa_mpagominimo_lag2"
# [466] "kmes_lag2"
# [467] "mpayroll_sobre_edad_lag2"
# [468] "ctrx_quarter_clon_lag2"
# [469] "active_quarter_delta1"
# [470] "active_quarter_delta2"
# [471] "cliente_vip_delta1"
# [472] "cliente_vip_delta2"
# [473] "internet_delta1"
# [474] "internet_delta2"
# [475] "cliente_edad_delta1"
# [476] "cliente_edad_delta2"
# [477] "cliente_antiguedad_delta1"
# [478] "cliente_antiguedad_delta2"
# [479] "mrentabilidad_delta1"
# [480] "mrentabilidad_delta2"
# [481] "mrentabilidad_annual_delta1"
# [482] "mrentabilidad_annual_delta2"
# [483] "mcomisiones_delta1"
# [484] "mcomisiones_delta2"
# [485] "mactivos_margen_delta1"
# [486] "mactivos_margen_delta2"
# [487] "mpasivos_margen_delta1"
# [488] "mpasivos_margen_delta2"
# [489] "cproductos_delta1"
# [490] "cproductos_delta2"
# [491] "tcuentas_delta1"
# [492] "tcuentas_delta2"
# [493] "ccuenta_corriente_delta1"
# [494] "ccuenta_corriente_delta2"
# [495] "mcuenta_corriente_adicional_delta1"
# [496] "mcuenta_corriente_adicional_delta2"
# [497] "mcuenta_corriente_delta1"
# [498] "mcuenta_corriente_delta2"
# [499] "ccaja_ahorro_delta1"
# [500] "ccaja_ahorro_delta2"
# [501] "mcaja_ahorro_delta1"
# [502] "mcaja_ahorro_delta2"
# [503] "mcaja_ahorro_adicional_delta1"
# [504] "mcaja_ahorro_adicional_delta2"
# [505] "mcaja_ahorro_dolares_delta1"
# [506] "mcaja_ahorro_dolares_delta2"
# [507] "cdescubierto_preacordado_delta1"
# [508] "cdescubierto_preacordado_delta2"
# [509] "mcuentas_saldo_delta1"
# [510] "mcuentas_saldo_delta2"
# [511] "ctarjeta_debito_delta1"
# [512] "ctarjeta_debito_delta2"
# [513] "ctarjeta_debito_transacciones_delta1"
# [514] "ctarjeta_debito_transacciones_delta2"
# [515] "mautoservicio_delta1"
# [516] "mautoservicio_delta2"
# [517] "ctarjeta_visa_delta1"
# [518] "ctarjeta_visa_delta2"
# [519] "ctarjeta_visa_transacciones_delta1"
# [520] "ctarjeta_visa_transacciones_delta2"
# [521] "mtarjeta_visa_consumo_delta1"
# [522] "mtarjeta_visa_consumo_delta2"
# [523] "ctarjeta_master_delta1"
# [524] "ctarjeta_master_delta2"
# [525] "ctarjeta_master_transacciones_delta1"
# [526] "ctarjeta_master_transacciones_delta2"
# [527] "mtarjeta_master_consumo_delta1"
# [528] "mtarjeta_master_consumo_delta2"
# [529] "cprestamos_personales_delta1"
# [530] "cprestamos_personales_delta2"
# [531] "mprestamos_personales_delta1"
# [532] "mprestamos_personales_delta2"
# [533] "cprestamos_prendarios_delta1"
# [534] "cprestamos_prendarios_delta2"
# [535] "mprestamos_prendarios_delta1"
# [536] "mprestamos_prendarios_delta2"
# [537] "cprestamos_hipotecarios_delta1"
# [538] "cprestamos_hipotecarios_delta2"
# [539] "mprestamos_hipotecarios_delta1"
# [540] "mprestamos_hipotecarios_delta2"
# [541] "cplazo_fijo_delta1"
# [542] "cplazo_fijo_delta2"
# [543] "mplazo_fijo_dolares_delta1"
# [544] "mplazo_fijo_dolares_delta2"
# [545] "mplazo_fijo_pesos_delta1"
# [546] "mplazo_fijo_pesos_delta2"
# [547] "cinversion1_delta1"
# [548] "cinversion1_delta2"
# [549] "minversion1_pesos_delta1"
# [550] "minversion1_pesos_delta2"
# [551] "minversion1_dolares_delta1"
# [552] "minversion1_dolares_delta2"
# [553] "cinversion2_delta1"
# [554] "cinversion2_delta2"
# [555] "minversion2_delta1"
# [556] "minversion2_delta2"
# [557] "cseguro_vida_delta1"
# [558] "cseguro_vida_delta2"
# [559] "cseguro_auto_delta1"
# [560] "cseguro_auto_delta2"
# [561] "cseguro_vivienda_delta1"
# [562] "cseguro_vivienda_delta2"
# [563] "cseguro_accidentes_personales_delta1"
# [564] "cseguro_accidentes_personales_delta2"
# [565] "ccaja_seguridad_delta1"
# [566] "ccaja_seguridad_delta2"
# [567] "cpayroll_trx_delta1"
# [568] "cpayroll_trx_delta2"
# [569] "mpayroll_delta1"
# [570] "mpayroll_delta2"
# [571] "mpayroll2_delta1"
# [572] "mpayroll2_delta2"
# [573] "cpayroll2_trx_delta1"
# [574] "cpayroll2_trx_delta2"
# [575] "ccuenta_debitos_automaticos_delta1"
# [576] "ccuenta_debitos_automaticos_delta2"
# [577] "mcuenta_debitos_automaticos_delta1"
# [578] "mcuenta_debitos_automaticos_delta2"
# [579] "ctarjeta_visa_debitos_automaticos_delta1"
# [580] "ctarjeta_visa_debitos_automaticos_delta2"
# [581] "mttarjeta_visa_debitos_automaticos_delta1"
# [582] "mttarjeta_visa_debitos_automaticos_delta2"
# [583] "ctarjeta_master_debitos_automaticos_delta1"
# [584] "ctarjeta_master_debitos_automaticos_delta2"
# [585] "mttarjeta_master_debitos_automaticos_delta1"
# [586] "mttarjeta_master_debitos_automaticos_delta2"
# [587] "cpagodeservicios_delta1"
# [588] "cpagodeservicios_delta2"
# [589] "mpagodeservicios_delta1"
# [590] "mpagodeservicios_delta2"
# [591] "cpagomiscuentas_delta1"
# [592] "cpagomiscuentas_delta2"
# [593] "mpagomiscuentas_delta1"
# [594] "mpagomiscuentas_delta2"
# [595] "ccajeros_propios_descuentos_delta1"
# [596] "ccajeros_propios_descuentos_delta2"
# [597] "mcajeros_propios_descuentos_delta1"
# [598] "mcajeros_propios_descuentos_delta2"
# [599] "ctarjeta_visa_descuentos_delta1"
# [600] "ctarjeta_visa_descuentos_delta2"
# [601] "mtarjeta_visa_descuentos_delta1"
# [602] "mtarjeta_visa_descuentos_delta2"
# [603] "ctarjeta_master_descuentos_delta1"
# [604] "ctarjeta_master_descuentos_delta2"
# [605] "mtarjeta_master_descuentos_delta1"
# [606] "mtarjeta_master_descuentos_delta2"
# [607] "ccomisiones_mantenimiento_delta1"
# [608] "ccomisiones_mantenimiento_delta2"
# [609] "mcomisiones_mantenimiento_delta1"
# [610] "mcomisiones_mantenimiento_delta2"
# [611] "ccomisiones_otras_delta1"
# [612] "ccomisiones_otras_delta2"
# [613] "mcomisiones_otras_delta1"
# [614] "mcomisiones_otras_delta2"
# [615] "cforex_delta1"
# [616] "cforex_delta2"
# [617] "cforex_buy_delta1"
# [618] "cforex_buy_delta2"
# [619] "mforex_buy_delta1"
# [620] "mforex_buy_delta2"
# [621] "cforex_sell_delta1"
# [622] "cforex_sell_delta2"
# [623] "mforex_sell_delta1"
# [624] "mforex_sell_delta2"
# [625] "ctransferencias_recibidas_delta1"
# [626] "ctransferencias_recibidas_delta2"
# [627] "mtransferencias_recibidas_delta1"
# [628] "mtransferencias_recibidas_delta2"
# [629] "ctransferencias_emitidas_delta1"
# [630] "ctransferencias_emitidas_delta2"
# [631] "mtransferencias_emitidas_delta1"
# [632] "mtransferencias_emitidas_delta2"
# [633] "cextraccion_autoservicio_delta1"
# [634] "cextraccion_autoservicio_delta2"
# [635] "mextraccion_autoservicio_delta1"
# [636] "mextraccion_autoservicio_delta2"
# [637] "ccheques_depositados_delta1"
# [638] "ccheques_depositados_delta2"
# [639] "mcheques_depositados_delta1"
# [640] "mcheques_depositados_delta2"
# [641] "ccheques_emitidos_delta1"
# [642] "ccheques_emitidos_delta2"
# [643] "mcheques_emitidos_delta1"
# [644] "mcheques_emitidos_delta2"
# [645] "ccheques_depositados_rechazados_delta1"
# [646] "ccheques_depositados_rechazados_delta2"
# [647] "mcheques_depositados_rechazados_delta1"
# [648] "mcheques_depositados_rechazados_delta2"
# [649] "ccheques_emitidos_rechazados_delta1"
# [650] "ccheques_emitidos_rechazados_delta2"
# [651] "mcheques_emitidos_rechazados_delta1"
# [652] "mcheques_emitidos_rechazados_delta2"
# [653] "tcallcenter_delta1"
# [654] "tcallcenter_delta2"
# [655] "ccallcenter_transacciones_delta1"
# [656] "ccallcenter_transacciones_delta2"
# [657] "thomebanking_delta1"
# [658] "thomebanking_delta2"
# [659] "chomebanking_transacciones_delta1"
# [660] "chomebanking_transacciones_delta2"
# [661] "ccajas_transacciones_delta1"
# [662] "ccajas_transacciones_delta2"
# [663] "ccajas_consultas_delta1"
# [664] "ccajas_consultas_delta2"
# [665] "ccajas_depositos_delta1"
# [666] "ccajas_depositos_delta2"
# [667] "ccajas_extracciones_delta1"
# [668] "ccajas_extracciones_delta2"
# [669] "ccajas_otras_delta1"
# [670] "ccajas_otras_delta2"
# [671] "catm_trx_delta1"
# [672] "catm_trx_delta2"
# [673] "matm_delta1"
# [674] "matm_delta2"
# [675] "catm_trx_other_delta1"
# [676] "catm_trx_other_delta2"
# [677] "matm_other_delta1"
# [678] "matm_other_delta2"
# [679] "ctrx_quarter_delta1"
# [680] "ctrx_quarter_delta2"
# [681] "tmobile_app_delta1"
# [682] "tmobile_app_delta2"
# [683] "cmobile_app_trx_delta1"
# [684] "cmobile_app_trx_delta2"
# [685] "Master_delinquency_delta1"
# [686] "Master_delinquency_delta2"
# [687] "Master_status_delta1"
# [688] "Master_status_delta2"
# [689] "Master_mfinanciacion_limite_delta1"
# [690] "Master_mfinanciacion_limite_delta2"
# [691] "Master_Fvencimiento_delta1"
# [692] "Master_Fvencimiento_delta2"
# [693] "Master_Finiciomora_delta1"
# [694] "Master_Finiciomora_delta2"
# [695] "Master_msaldototal_delta1"
# [696] "Master_msaldototal_delta2"
# [697] "Master_msaldopesos_delta1"
# [698] "Master_msaldopesos_delta2"
# [699] "Master_msaldodolares_delta1"
# [700] "Master_msaldodolares_delta2"
# [701] "Master_mconsumospesos_delta1"
# [702] "Master_mconsumospesos_delta2"
# [703] "Master_mconsumosdolares_delta1"
# [704] "Master_mconsumosdolares_delta2"
# [705] "Master_mlimitecompra_delta1"
# [706] "Master_mlimitecompra_delta2"
# [707] "Master_madelantopesos_delta1"
# [708] "Master_madelantopesos_delta2"
# [709] "Master_madelantodolares_delta1"
# [710] "Master_madelantodolares_delta2"
# [711] "Master_fultimo_cierre_delta1"
# [712] "Master_fultimo_cierre_delta2"
# [713] "Master_mpagado_delta1"
# [714] "Master_mpagado_delta2"
# [715] "Master_mpagospesos_delta1"
# [716] "Master_mpagospesos_delta2"
# [717] "Master_mpagosdolares_delta1"
# [718] "Master_mpagosdolares_delta2"
# [719] "Master_fechaalta_delta1"
# [720] "Master_fechaalta_delta2"
# [721] "Master_mconsumototal_delta1"
# [722] "Master_mconsumototal_delta2"
# [723] "Master_cconsumos_delta1"
# [724] "Master_cconsumos_delta2"
# [725] "Master_cadelantosefectivo_delta1"
# [726] "Master_cadelantosefectivo_delta2"
# [727] "Master_mpagominimo_delta1"
# [728] "Master_mpagominimo_delta2"
# [729] "Visa_delinquency_delta1"
# [730] "Visa_delinquency_delta2"
# [731] "Visa_status_delta1"
# [732] "Visa_status_delta2"
# [733] "Visa_mfinanciacion_limite_delta1"
# [734] "Visa_mfinanciacion_limite_delta2"
# [735] "Visa_Fvencimiento_delta1"
# [736] "Visa_Fvencimiento_delta2"
# [737] "Visa_Finiciomora_delta1"
# [738] "Visa_Finiciomora_delta2"
# [739] "Visa_msaldototal_delta1"
# [740] "Visa_msaldototal_delta2"
# [741] "Visa_msaldopesos_delta1"
# [742] "Visa_msaldopesos_delta2"
# [743] "Visa_msaldodolares_delta1"
# [744] "Visa_msaldodolares_delta2"
# [745] "Visa_mconsumospesos_delta1"
# [746] "Visa_mconsumospesos_delta2"
# [747] "Visa_mconsumosdolares_delta1"
# [748] "Visa_mconsumosdolares_delta2"
# [749] "Visa_mlimitecompra_delta1"
# [750] "Visa_mlimitecompra_delta2"
# [751] "Visa_madelantopesos_delta1"
# [752] "Visa_madelantopesos_delta2"
# [753] "Visa_madelantodolares_delta1"
# [754] "Visa_madelantodolares_delta2"
# [755] "Visa_fultimo_cierre_delta1"
# [756] "Visa_fultimo_cierre_delta2"
# [757] "Visa_mpagado_delta1"
# [758] "Visa_mpagado_delta2"
# [759] "Visa_mpagospesos_delta1"
# [760] "Visa_mpagospesos_delta2"
# [761] "Visa_mpagosdolares_delta1"
# [762] "Visa_mpagosdolares_delta2"
# [763] "Visa_fechaalta_delta1"
# [764] "Visa_fechaalta_delta2"
# [765] "Visa_mconsumototal_delta1"
# [766] "Visa_mconsumototal_delta2"
# [767] "Visa_cconsumos_delta1"
# [768] "Visa_cconsumos_delta2"
# [769] "Visa_cadelantosefectivo_delta1"
# [770] "Visa_cadelantosefectivo_delta2"
# [771] "Visa_mpagominimo_delta1"
# [772] "Visa_mpagominimo_delta2"
# [773] "kmes_delta1"
# [774] "kmes_delta2"
# [775] "mpayroll_sobre_edad_delta1"
# [776] "mpayroll_sobre_edad_delta2"
# [777] "ctrx_quarter_clon_delta1"
# [778] "ctrx_quarter_clon_delta2"

# %% [markdown]
# #### 8.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 8.3.2 Modelado

# %% [markdown]
# #### 8.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  con un undersampling de los CONTINUA del 2% por un tema de velocidad
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105, 202104)

PARAM$trainingstrategy$training <- c(
  202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005, 202004, 202003
)

PARAM$trainingstrategy$training_pct <- 0.1


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 327335

# %% [markdown]
# ####  8.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 50

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  extra_trees = FALSE,

  ### FEATURE FRACTION ###  
  feature_fraction = 1.0,

  max_depth = -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split = 0.0, # min_gain_to_split >= 0.0
  min_sum_hessian_in_leaf = 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1 = 0.0, # lambda_l1 >= 0.0
  lambda_l2 = 0.0, # lambda_l2 >= 0.0

  bagging_fraction = 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction = 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction = 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance = FALSE, #
  scale_pos_weight = 1.0, # scale_pos_weight > 0.0

  drop_rate = 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop = 50, # <=0 means no limit
  skip_drop = 0.5, # 0.0 <= skip_drop <= 1.0

  max_bin= 31,
  num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate", lower = 0.02, upper = 0.3),
  makeNumericParam("coverage", lower = 0.05, upper = 1.0), # nuevo
  makeNumericParam("leaf_size", lower = 0.001, upper = 0.2) # nuevo
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  message(format(Sys.time(), "%a %b %d %X %Y"))

  # uno la lista de hiperparametros : fijos + variables
  param_completo <- c(PARAM$lgbm$param_fijos, x)

  # hago la transformacion de leaf_size y  coverage
  if( "leaf_size"  %in% names(param_completo) &
      "coverage"  %in% names(param_completo)
  )
  {
    # primero defino el tamaño de las hojas
    param_completo$min_data_in_leaf <- pmax( 1,  round( nrow(dtrain) * param_completo$leaf_size )  )
    # luego la cantidad de hojas en funcion del valor anterior, el coverage, y la cantidad de registros
    param_completo$num_leaves <- pmin( 131072,
      pmax( 8,  round( ( param_completo$coverage * nrow( dtrain ) / param_completo$min_data_in_leaf ) ) ))
  }

  if( "leaf_size"  %in% names(param_completo) &
      !( "coverage"  %in% names(param_completo) )
  )
  {
    # primero defino el tamaño de las hojas
    param_completo$min_data_in_leaf <- pmax( 1,  round( nrow(dtrain) * param_completo$leaf_size )  )
  }


  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Warning message in mboContinue("HT.RDATA"):
# “Tuning ended with term.iter. No need to continue. Simply returning stored result.”

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  list(learning_rate, coverage, leaf_size)
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    learning_rate  coverage   leaf_size
#            <num>     <num>       <num>
# 1:    0.02000537 0.6034876 0.004249451

# %% [markdown]
# ### 8.3.3 Produccion Semillerio

# %% [markdown]
# ### Final Training Semillerio
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c( 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007, 202006, 202005, 202004, 202003
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 2365834

# %% [markdown]
# #### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# hago la transformacion de leaf_size y  coverage
  if( "leaf_size"  %in% names(param_final) &
      "coverage"  %in% names(param_final)
  )
  {
    # primero defino el tamaño de las hojas
    param_final$min_data_in_leaf <- pmax( 1,  round( nrow(dfinal_train) * param_final$leaf_size )  )
    # luego la cantidad de hojas en funcion del valor anterior, el coverage, y la cantidad de registros
    param_final$num_leaves <- pmin( 131072,
      pmax( 8,  round( ( param_final$coverage * nrow( dfinal_train ) / param_final$min_data_in_leaf ) ) ))
  }

  if( "leaf_size"  %in% names(param_final) &
      !( "coverage"  %in% names(param_final) )
  )
  {
    # primero defino el tamaño de las hojas
    param_final$min_data_in_leaf <- pmax( 1,  round( nrow(dfinal_train) * param_final$leaf_size )  )
  }

# %%
param_final
# Out:
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] TRUE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $verbosity
# [1] -100
#
# $force_row_wise
# [1] TRUE
#
# $seed
# [1] 314159
#
# $extra_trees
# [1] FALSE
#
# $feature_fraction
# [1] 1
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $max_bin
# [1] 31
#
# $learning_rate
# [1] 0.02000537
#
# $coverage
# [1] 0.6034876
#
# $leaf_size
# [1] 0.004249451
#
# $min_data_in_leaf
# [1] 10053
#
# $num_leaves
# [1] 142

# %% [markdown]
# #### Training  Semillerio
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %% [markdown]
# ### Aqui va cuantas semillas utilizo para el semillerio

# %%
# semillerio
PARAM$FT$semillerio <- 20  # cantidad de semillas

# %%
# semillerio
if(!require("primes")) install.packages("primes")
require("primes")
# Out:
# Loading required package: primes

# %%
# semillerio
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
# me quedo con PARAM$semillerio  primos al azar
PARAM$FT$semillas <- sample(primos)[seq(PARAM$FT$semillerio)]

cat( PARAM$FT$semillas)
# Out:
# 303491 249229 867389 440537 752023 162517 952859 623059 887191 181399 704281 420779 481097 206527 184417 393451 429551 742369 885383 889411

# %%
# semillerio
dir.create("modelos", showWarnings =FALSE)

primero <- TRUE
for( sem in PARAM$FT$semillas)
{
  nombre_arch <- paste0( "./modelos/modelo_", sem, ".txt")
  if( !file.exists(nombre_arch) )
  {
    param_final$seed <- sem

    set.seed(sem, kind = "L'Ecuyer-CMRG")
    final_model <- lgb.train(
      data= dfinal_train,
      param= param_final,
      verbose= -100
    )

    lgb.save(final_model, nombre_arch) # grabo el modelo"

    # grabo la primer importancia de variables
    #  Natalia : da lo mismo cual se guarda
    if( primero)
    {
      primero <- FALSE
      tb_importancia <- as.data.table(lgb.importance(final_model))
      archivo_importancia <- "impo.txt"

      fwrite( tb_importancia,
        file= archivo_importancia,
        sep= "\t"
      )
    }
 }
}

# %% [markdown]
# ### Scoring Semillerio

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# semillerio aplico final_model   a dfuture

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := 0]

datos_matrix <- data.matrix(dfuture[, campos_buenos, with= FALSE])


for( isem in seq(length(PARAM$FT$semillas)) )
{
   sem <- PARAM$FT$semillas[ isem ]
   nombre_arch <- paste0( "./modelos/modelo_", sem, ".txt")
   final_model <- lgb.load(nombre_arch)

   prediccion <- predict(
     final_model,
     datos_matrix
  )

  tb_prediccion[, paste0("prob_", isem) := prediccion]
  tb_prediccion[, prob := prob + prediccion]

  rm(final_model)
  rm(prediccion)
  gc(full = TRUE, verbose=FALSE)
}

rm( datos_matrix)
gc(full = TRUE, verbose=FALSE)

tb_prediccion[, prob := prob /length(PARAM$FT$semillas) 
# 27     0.003001868 0.003001868 0.003001868 0.003001868
# 28     0.001187636 0.001187636 0.001187636 0.001187636
# 29     0.003346405 0.003346405 0.003346405 0.003346405
# 30     0.001413256 0.001413256 0.001413256 0.001413256
# ⋮      ⋮           ⋮           ⋮           ⋮
# 164567 0.003759857 0.003759857 0.003759857 0.003759857
# 164568 0.006765750 0.006765750 0.006765750 0.006765750
# 164569 0.017005546 0.017005546 0.017005546 0.017005546
# 164570 0.020974306 0.020974306 0.020974306 0.020974306
# 164571 0.008579949 0.008579949 0.008579949 0.008579949
# 164572 0.004804921 0.004804921 0.004804921 0.004804921
# 164573 0.020626288 0.020626288 0.020626288 0.020626288
# 164574 0.015018706 0.015018706 0.015018706 0.015018706
# 164575 0.017101987 0.017101987 0.017101987 0.017101987
# 164576 0.017101987 0.017101987 0.017101987 0.017101987
# 164577 0.017101987 0.017101987 0.017101987 0.017101987
# 164578 0.041473877 0.041473877 0.041473877 0.041473877
# 164579 0.006169400 0.006169400 0.006169400 0.006169400
# 164580 0.021229472 0.021229472 0.021229472 0.021229472
# 164581 0.006117346 0.006117346 0.006117346 0.006117346
# 164582 0.017313996 0.017313996 0.017313996 0.017313996
# 164583 0.025675409 0.025675409 0.025675409 0.025675409
# 164584 0.004528258 0.004528258 0.004528258 0.004528258
# 164585 0.005071817 0.005071817 0.005071817 0.005071817
# 164586 0.020886085 0.020886085 0.020886085 0.020886085
# 164587 0.026168753 0.026168753 0.026168753 0.026168753
# 164588 0.017500518 0.017500518 0.017500518 0.017500518
# 164589 0.007156556 0.007156556 0.007156556 0.007156556
# 164590 0.021060403 0.021060403 0.021060403 0.021060403
# 164591 0.005860561 0.005860561 0.005860561 0.005860561
# 164592 0.010837796 0.010837796 0.010837796 0.010837796
# 164593 0.020150370 0.020150370 0.020150370 0.020150370
# 164594 0.026239803 0.026239803 0.026239803 0.026239803
# 164595 0.004877599 0.004877599 0.004877599 0.004877599
# 164596 0.020974306 0.020974306 0.020974306 0.020974306

# %%
# Agregamos la clase real al tb_prediccion para poder evaluar wilcoxon luego
tb_prediccion <- tb_prediccion[, clase_ternaria := dfuture$clase_ternaria]

# %%
# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos

fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %%
# inicializamos data.table
tb_ganancias <- data.table(isem = integer(), max_gain = numeric())

# loop para maximos de ganancia
for (isem in seq(length(PARAM$FT$semillas))){
    # cliente | prob_isem | clase
    pred <- tb_prediccion[, c("numero_de_cliente",  paste0("prob_", isem), "clase_ternaria"), with = FALSE]

    # Ordenar por probabilidad descendente
    pred <- pred[order(-get(paste0("prob_", isem)))]

    # Calcular ganancia y ganancia acumulada
    pred[, Ganancia := ifelse(clase_ternaria == "BAJA+2", 117000, -3000)]
    pred[, Ganancia_acum := cumsum(Ganancia)]

    # Seleccionar ciertas filas
    pred <- pred[seq(6000, 14000, 100),]

    # Seleccionamos el máximo
    max_gain <- max(pred[, Ganancia_acum])

    tb_ganancias <- rbind(tb_ganancias, data.table(isem = isem, max_gain = max_gain))

}

fwrite(tb_ganancias,
  file= "tb_ganancias.txt",
  sep= "\t"
)

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 10 01:47:33 2025"
